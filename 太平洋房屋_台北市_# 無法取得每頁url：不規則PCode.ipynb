# %%
import requests
from bs4 import BeautifulSoup
from math import ceil

headers = {'Cookie':'ASP.NET_SessionId=c020uya4qzsebwcih2wmdhkj; _gat=1; _ga=GA1.3.1450127955.1438694495'}
res = requests.get('http://www.pacific.com.tw/HouseList.aspx?PCode=9BCF263139F1',headers = headers)
#print res.text
soup = BeautifulSoup(res.text)

# get pages of cases:10 cases per page
pages = soup.select('#ctl00_ctl00_Main_Main_DropDownListPage option')
pages = len(pages)
print pages
# Out:
# 99

# %%
# 取得頁面上連結
for ele in soup.select('.HouseList a'):
    if len(ele.text) > 0:
        print 'http://www.pacific.com.tw/'+ele['href']
# Out:
# http://www.pacific.com.tw/HouseDetail.aspx?ID=52831128
# http://www.pacific.com.tw/HouseDetail.aspx?ID=54895737
# http://www.pacific.com.tw/HouseDetail.aspx?ID=54480069
# http://www.pacific.com.tw/HouseDetail.aspx?ID=54894793
# http://www.pacific.com.tw/HouseDetail.aspx?ID=54476803
# http://www.pacific.com.tw/HouseDetail.aspx?ID=54750399
# http://www.pacific.com.tw/HouseDetail.aspx?ID=54472999
# http://www.pacific.com.tw/HouseDetail.aspx?ID=54120706
# http://www.pacific.com.tw/HouseDetail.aspx?ID=53619688
# http://www.pacific.com.tw/HouseDetail.aspx?ID=54750699

# %%
# 將每頁連結存入檔案
f = open('pacific/pacific.txt','w')

page_format = 'http://home.etwarm.com.tw/object_search.php?p={}&pap=&mo=&orderby=price&ettype=SALES&ci=%E5%8F%B0%E5%8C%97%E5%B8%82%2C&pr1=%E4%B8%8D%E9%99%90&pr2=%E4%B8%8D%E9%99%90&pa1=%E4%B8%8D%E9%99%90&pa2=%E4%B8%8D%E9%99%90&t=&pi1=%E4%B8%8D%E9%99%90&pi2=%E4%B8%8D%E9%99%90&q=%E8%AB%8B%E8%BC%B8%E5%85%A5%E9%97%9C%E9%8D%B5%E5%AD%97%EF%BC%8C%E5%8F%AF%E4%B8%8D%E5%A1%AB&pk=&old1=%E4%B8%8D%E9%99%90&old2=%E4%B8%8D%E9%99%90'
for page in range(1, pages +1):

    res = requests.get(page_format.format(page))
    #print page +'finished.'
    soup = BeautifulSoup(res.text)
    for ele in soup.select('.Search-Ob-all a'):
        if len(ele.text) > 0:
            #print 'http://home.etwarm.com.tw'+ele['href'][1:]
            f.write('http://home.etwarm.com.tw'+ele['href'][1:]+'\n')
f.close()

# %%
form = {'ctl00_ctl00_Main_Main_HouseSearch1_TabContainer1_ClientState':'{"ActiveTabIndex":0,"TabState":[true,true,true,true,true]}','__EVENTTARGET':'','__EVENTARGUMENT':'','__LASTFOCUS':'','__VIEWSTATE':'...','__VIEWSTATEGENERATOR':'B143AA21','__VIEWSTATEENCRYPTED':'','__EVENTVALIDATION':'...','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel11$ddlAddr1':'台北市','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel11$ddlAddr2':'X','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel11$ddlAmt1':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel11$ddlAmt2':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel11$ddlL1':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel11$ddlL2':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel11$ddlP1':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel11$ddlP2':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel11$ddlAge1':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel11$ddlAge2':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel11$ddlHType':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel11$TextSearch':'','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel11$TextBoxWatermarkExtender1_ClientState':'','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel12$ddlAddr1_2':'台北市','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel12$ddlAddr2_2':'X','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel12$ddlAmt1_2':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel12$ddlAmt2_2':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel12$ddlL1_2':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel12$ddlL2_2':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel12$ddlP1_2':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel12$ddlP2_2':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel12$ddlAge1_2':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel12$ddlAge2_2':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel12$ddlHType_2':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel1$ddlMRT1':'X','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel1$ddlMRT2':'X','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel1$ddlMRT3':'X','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel1$ddlAmt1_3':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel1$ddlAmt2_3':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel1$ddlL1_3':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel1$ddlL2_3':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel1$ddlP1_3':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel1$ddlP2_3':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel1$ddlAge1_3':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel1$ddlAge2_3':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel1$ddlHType_3':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel2$ddlRail':'13','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel3$ddlAddr1_5':'台北市','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel3$ddlAddr2_5':'X','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel3$ddlAmt1_5':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel3$ddlAmt2_5':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel3$ddlL1_5':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel3$ddlL2_5':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel3$ddlP1_5':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel3$ddlP2_5':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel3$ddlAge1_5':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel3$ddlAge2_5':'999999','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel3$ddlHType_5':'0','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel3$TextBox1':'','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel3$TextBoxWatermarkExtender2_ClientState':'','ctl00$ctl00$Main$Main$DropDownListPage':'1','ctl00$ctl00$Main$Main$ImageButtonNext.x':'4','ctl00$ctl00$Main$Main$ImageButtonNext.y':'6'}

# %%
# 取得每頁url:不規則P-code
form = {'ctl00$ctl00$Main$Main$DropDownListPage':'2','ctl00$ctl00$Main$Main$HouseSearch1$TabContainer1$TabPanel3$ddlAddr1_5':'台北市'}
url = 'http://www.pacific.com.tw/HouseList.aspx?PCode=185EAC3FFAAB'
res = requests.post(url, data = form, headers = headers)
#print res.text
